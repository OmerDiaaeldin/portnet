# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 500)

# %%
ds = pd.read_csv("Datasets/dynamic_supply_chain_logistics_dataset.csv")
dp = pd.read_csv("Datasets/Daily_Port_Activity_Data_and_Trade_Estimates.csv")
tangier = pd.read_excel('Datasets/CMACGM-TANGER - MED - (MA) - Port - Schedules-20250210 - 210531.xlsx')
# Out:
# /home/odaio/dev/dump/env/lib/python3.13/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
ds.head()
# Out:
#              timestamp  vehicle_gps_latitude  vehicle_gps_longitude  \
# 0  2021-01-01 00:00:00             40.375568             -77.014318
# 1  2021-01-01 01:00:00             33.507818            -117.036902
# 2  2021-01-01 02:00:00             30.020640             -75.269224
# 3  2021-01-01 03:00:00             36.649223             -70.190529
# 4  2021-01-01 04:00:00             30.001279             -70.012195
#
#    fuel_consumption_rate  eta_variation_hours  traffic_congestion_level  \
# 0               5.136512             4.998009                  5.927586
# 1               5.101512             0.984929                  1.591992
# 2               5.090803             4.972665                  8.787765
# 3               8.219558             3.095064                  0.045257
# 4               5.000075             3.216077                  8.004851
#
#    warehouse_inventory_level  loading_unloading_time  \
# 0                 985.716862                4.951392
# ...

# %%
filtered_df = dp[dp['country'] == 'Morocco']
filtered_df.tail()
# Out:
#                            date  year  month  day   portid    portname  \
# 3426793  2024/05/31 00:00:00+00  2024      5   31  port971  Port Nador
# 3426794  2024/09/09 00:00:00+00  2024      9    9  port971  Port Nador
# 3426796  2024/06/01 00:00:00+00  2024      6    1  port971  Port Nador
# 3426797  2024/09/10 00:00:00+00  2024      9   10  port971  Port Nador
# 3426799  2024/06/02 00:00:00+00  2024      6    2  port971  Port Nador
#
#          country ISO3  portcalls_container  portcalls_dry_bulk  \
# 3426793  Morocco  MAR                    0                   0
# 3426794  Morocco  MAR                    0                   0
# 3426796  Morocco  MAR                    0                   0
# 3426797  Morocco  MAR                    0                   0
# 3426799  Morocco  MAR                    0                   0
#
#          portcalls_general_cargo  portcalls_roro  portcalls_tanker  \
# 3426793                        1               0                 0
# ...

# %%
tangier.head()
# Out:
#         Vessel Name     Voyage Local Voyage  \
# 0     NORDIC ITALIA  0WRO8W1MA          NaN
# 1      CMA CGM LEBU  0BAKJS1MA          NaN
# 2   CMA CGM MONTOIR  0HFMNN1MA          NaN
# 3  CMA CGM VOLTAIRE  0DVL9S1MA          NaN
# 4    ATLANTIC GREEN     37S3JR          NaN
#
#                                             Service             ETA Berth  \
# 0                  SSLMED Agapome Service (AGAPOME)  2/12/2025 7:00:00 AM
# 1                         Europe Afrique 1 (EURAF1)  2/13/2025 1:00:00 AM
# 2          SSLMED Femex 1 - Aegean Shuttle (FEMEX1)  2/17/2025 1:00:00 AM
# 3                Mediterranean Caribbean (MEDCARIB)  2/12/2025 6:00:00 PM
# 4  SSLEUR Algeciras Bilbao Feeder (ACX1) (ESALGBIF)  2/14/2025 2:00:00 AM
#
#                      ETD                   Terminal           Port Cut-off  \
# 0   2/13/2025 5:00:00 AM  EUROGATE TERMINAL TANGIER   2/8/2025 11:30:00 AM
# 1   2/14/2025 1:00:00 AM  EUROGATE TERMINAL TANGIER    2/9/2025 6:00:00 PM
# ...

# %%
tangier.describe()
# Out:
#            Vessel Name     Voyage Local Voyage  \
# count              899        899            8
# unique             165        856            3
# top     CMA CGM DAKHLA  0NSKJS1MA         507S
# freq                50          3            4
#
#                                     Service            ETA Berth  \
# count                                   899                  899
# unique                                   28                  802
# top     SSLMED NC Levant Express (NCLEVANT)  9/1/2025 7:00:00 AM
# freq                                     54                    3
#
#                          ETD                   Terminal  \
# count                    899                        899
# unique                   832                          4
# top     2/21/2025 7:00:00 AM  EUROGATE TERMINAL TANGIER
# freq                       3                        683
#
#                  Port Cut-off Special Booking Cut-off  \
# count                     714                     714
# ...

# %%
tangier.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 899 entries, 0 to 898
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Vessel Name               899 non-null    object
#  1   Voyage                    899 non-null    object
#  2   Local Voyage              8 non-null      object
#  3   Service                   899 non-null    object
#  4   ETA Berth                 899 non-null    object
#  5   ETD                       899 non-null    object
#  6   Terminal                  899 non-null    object
#  7   Port Cut-off              714 non-null    object
#  8   Special Booking Cut-off   714 non-null    object
#  9   Standard Booking Cut-off  714 non-null    object
#  10  VGM Cut-off               714 non-null    object
#  11  SI Cut-off                714 non-null    object
# dtypes: object(12)
# memory usage: 84.4+ KB
